# %%
# %matplotlib widget

import numpy as np
import matplotlib.pyplot as plt
import os

import lightkurve as lk

# %%
import pandas as pd

folder = '.'
file_path = os.path.join(folder, 'Data Files/Eclipsing CVs.csv')
df = pd.read_csv(file_path)

df.dtypes
# Out:
# TIC ID                                                              object
# Other name                                                          object
# CV Type                                                             object
# Paper                                                               object
# Link                                                                object
# Key:                                                                object
# Unnamed: 6                                                          object
# https://iopscience.iop.org/article/10.3847/1538-4357/abf2bc/pdf    float64
# dtype: object

# %%
for i in df['TIC ID']:
    try:
        int(i)
        print(lk.search_lightcurve(f'TIC {i}'))
    except:
        pass
# Out:
# SearchResult containing 5 data products.
#
#  #     mission     year  author exptime  target_name  distance
#                                    s                   arcsec
# --- -------------- ---- ------- ------- ------------- --------
#   0 K2 Campaign 07 2015      K2      60 ktwo214539533      0.0
#   1 K2 Campaign 07 2015      K2    1800 ktwo214539533      0.0
#   2 K2 Campaign 07 2015 EVEREST    1800 ktwo214539533      0.0
#   3 K2 Campaign 07 2015    K2SC    1800 ktwo214539533      0.0
#   4 K2 Campaign 07 2015   K2SFF    1800 ktwo214539533      0.0
# SearchResult containing 12 data products.
#
#  #     mission     year   author  exptime target_name distance
#                                      s                 arcsec
# --- -------------- ---- --------- ------- ----------- --------
#   0 TESS Sector 19 2019      SPOC     120     3034524      0.0
#   1 TESS Sector 43 2021      SPOC     120     3034524      0.0
#   2 TESS Sector 44 2021      SPOC     120     3034524      0.0
#   3 TESS Sector 45 2021      SPOC     120     3034524      0.0
#   4 TESS Sector 59 2022      SPOC     120     3034524      0.0
#   5 TESS Sector 71 2023      SPOC     120     3034524      0.0
#   6 TESS Sector 73 2023      SPOC     120     3034524      0.0
#   7 TESS Sector 19 2019 TESS-SPOC    1800     3034524      0.0
#   8 TESS Sector 43 2021 TESS-SPOC     600     3034524      0.0
#   9 TESS Sector 44 2021 TESS-SPOC     600     3034524      0.0
#  10 TESS Sector 45 2021 TESS-SPOC     600     3034524      0.0
#  11 TESS Sector 59 2022 TESS-SPOC     200     3034524      0.0
# SearchResult containing 4 data products.
#
#  #     mission     year   author  exptime target_name distance
#                                      s                 arcsec
# --- -------------- ---- --------- ------- ----------- --------
#   0 TESS Sector 35 2021      SPOC     120     5393020      0.0
#   1 TESS Sector 62 2023      SPOC     120     5393020      0.0
#   2 TESS Sector 35 2021 TESS-SPOC     600     5393020      0.0
#   3 TESS Sector 62 2023 TESS-SPOC     200     5393020      0.0
# SearchResult containing 12 data products.
#
#  #     mission     year       author      exptime target_name distance
#                                              s                 arcsec
# --- -------------- ---- ----------------- ------- ----------- --------
#   0 TESS Sector 10 2019              SPOC     120     9560142      0.0
#   1 TESS Sector 37 2021              SPOC      20     9560142      0.0
#   2 TESS Sector 37 2021              SPOC     120     9560142      0.0
#   3 TESS Sector 64 2023              SPOC      20     9560142      0.0
#   4 TESS Sector 64 2023              SPOC     120     9560142      0.0
#   5 TESS Sector 10 2019         TESS-SPOC    1800     9560142      0.0
#   6 TESS Sector 37 2021         TESS-SPOC     600     9560142      0.0
#   7 TESS Sector 64 2023         TESS-SPOC     200     9560142      0.0
#   8 TESS Sector 10 2019               QLP    1800     9560142      0.0
#   9 TESS Sector 37 2021               QLP     600     9560142      0.0
#  10 TESS Sector 64 2023               QLP     200     9560142      0.0
#  11 TESS Sector 10 2019 GSFC-ELEANOR-LITE    1800     9560142      0.0
# SearchResult containing 4 data products.
#
#  #     mission     year   author  exptime target_name distance
#                                      s                 arcsec
# --- -------------- ---- --------- ------- ----------- --------
#   0 TESS Sector
#   8 TESS Sector 17 2019       QLP    1800   403308597      0.0
#   9 TESS Sector 24 2020       QLP    1800   403308597      0.0
#  10 TESS Sector 57 2022       QLP     200   403308597      0.0
#  11 TESS Sector 58 2022       QLP     200   403308597      0.0
# SearchResult containing 5 data products.
#
#  #     mission     year  author  exptime  target_name  distance
#                                     s                   arcsec
# --- -------------- ---- -------- ------- ------------- --------
#   0 K2 Campaign 02 2014       K2      60 ktwo205389468      0.0
#   1 K2 Campaign 02 2014       K2    1800 ktwo205389468      0.0
#   2 K2 Campaign 02 2014  EVEREST    1800 ktwo205389468      0.0
#   3 K2 Campaign 02 2014    K2SFF    1800 ktwo205389468      0.0
#   4 K2 Campaign 02 2014 K2VARCAT    1800 ktwo205389468      0.0
# SearchResult containing 6 data products.
#
#  #     mission     year       author      exptime target_name distance
#                                              s                 arcsec
# --- -------------- ---- ----------------- ------- ----------- --------
#   0 TESS Sector 34 2021              SPOC     120   437220261      0.0
#   1 TESS Sector 34 2021         TESS-SPOC     600   437220261      0.0
#   2 TESS Sector 07 2019 GSFC-ELEANOR-LITE    1800   437220261      0.0
#   3 TESS Sector 08 2019 GSFC-ELEANOR-LITE    1800   437220261      0.0
#   4 TESS Sector 07 2019              TGLC    1800   437220261      0.0
#   5 TESS Sector 08 2019              TGLC    1800   437220261      0.0
# SearchResult containing 4 data products.
#
#  #     mission     year   author  exptime target_name distance
#                                      s                 arcsec
# --- -------------- ---- --------- ------- ----------- --------
#   0 TESS Sector 17 2019      SPOC     120   440666925      0.0
#   1 TESS Sector 57 2022      SPOC     120   440666925      0.0
#   2 TESS Sector 17 2019 TESS-SPOC    1800   440666925      0.0
#   3 TESS Sector 57 2022 TESS-SPOC     200   440666925      0.0
# SearchResult containing 8 data products.
#
#  #     mission     year       author      exptime target_name distance
#                                              s                 arcsec
# --- -------------- ---- ----------------- ------- ----------- --------
#   0 TESS Sector 05 2018              SPOC     120   454190342      0.0
#   1 TESS Sector 32 2020              SPOC      20   454190342      0.0
#   2 TESS Sector 32 2020              SPOC     120   454190342      0.0
#   3 TESS Sector 05 2018         TESS-SPOC    1800   454190342      0.0
#   4 TESS Sector 32 2020         TESS-SPOC     600   454190342      0.0
#   5 TESS Sector 05 2018             TASOC     120   454190342      0.0
#   6 TESS Sector 05 2018 GSFC-ELEANOR-LITE    1800   454190342      0.0
#   7 TESS Sector 05 2018              TGLC    1800   454190342      0.0
# SearchResult containing 5 data products.
#
#  #     mission     year   author  exptime target_name distance
#                                      s                 arcsec
# --- -------------- ---- --------- ------- ----------- --------
#   0 TESS Sector 24 2020      SPOC     120   459276247      0.0
#   1 TESS Sector 51 2022      SPOC     120   459276247      0.0
#   2 TESS Sector 78 2024      SPOC     120   459276247      0.0
#   3 TESS Sector 24 2020 TESS-SPOC    1800   459276247      0.0
#   4 TESS Sector 51 2022 TESS-SPOC     600   459276247      0.0
# No data found for target "TIC 462792328".
# SearchResult containing 0 data products.
# No data found for target "TIC 686512970".
# SearchResult containing 0 data products.
# No data found for target "TIC 802128842".
# SearchResult containing 0 data products.
# SearchResult containing 4 data products.
#
#  #     mission     year   author  exptime target_name distance
#                                      s                 arcsec
# --- -------------- ---- --------- ------- ----------- --------
#   0 TESS Sector 35 2021      SPOC     120   842120088      0.0
#   1 TESS Sector 61 2023      SPOC     120   842120088      0.0
#   2 TESS Sector 35 2021 TESS-SPOC     600   842120088      0.0
#   3 TESS Sector 61 2023 TESS-SPOC     200   842120088      0.0
# SearchResult containing 1 data products.
#
#  #     mission     year author exptime target_name distance
#                                   s                 arcsec
# --- -------------- ---- ------ ------- ----------- --------
#   0 TESS Sector 72 2023   SPOC     120   842270790      0.0
# No data found for target "TIC 900017950".
# SearchResult containing 0 data products.
# No data found for target "TIC 900160698".
# SearchResult containing 0 data products.
# SearchResult containing 2 data products.
#
#  #     mission     year author exptime target_name distance
#                                   s                 arcsec
# --- -------------- ---- ------ ------- ----------- --------
#   0 TESS Sector 75 2024   SPOC     120   950508354      0.0
#   1 TESS Sector 76 2024   SPOC     120   950508354      0.0
# SearchResult containing 2 data products.
#
#  #     mission     year author exptime target_name distance
#                                   s                 arcsec
# --- -------------- ---- ------ ------- ----------- --------
#   0 TESS Sector 75 2024   SPOC     120  1001410470      0.0
#   1 TESS Sector 76 2024   SPOC     120  1001410470      0.0
# No data found for target "TIC 1001915222".
# SearchResult containing 0 data products.
# SearchResult containing 2 data products.
#
#  #     mission     year   author  exptime target_name distance
#                                      s                 arcsec
# --- -------------- ---- --------- ------- ----------- --------
#   0 TESS Sector 51 2022      SPOC     120  1002384236      0.0
#   1 TESS Sector 51 2022 TESS-SPOC     600  1002384236      0.0
# SearchResult containing 1 data products.
#
#  #     mission     year author exptime target_name distance
#                                   s                 arcsec
# --- -------------- ---- ------ ------- ----------- --------
#   0 TESS Sector 78 2024   SPOC     120  1100916855      0.0
# SearchResult containing 4 data products.
#
#  #     mission     year   author  exptime target_name distance
#                                      s                 arcsec
# --- -------------- ---- --------- ------- ----------- --------
#   0 TESS Sector 50 2022      SPOC     120  1102138697      0.0
#   1 TESS Sector 76 2024      SPOC     120  1102138697      0.0
#   2 TESS Sector 77 2024      SPOC     120  1102138697      0.0
#   3 TESS Sector 50 2022 TESS-SPOC     600  1102138697      0.0
# SearchResult containing 4 data products.
#
#  #     mission     year   author  exptime target_name distance
#                                      s                 arcsec
# --- -------------- ---- --------- ------- ----------- --------
#   0 TESS Sector 49 2022      SPOC     120  1102145986      0.0
#   1 TESS Sector 50 2022      SPOC     120  1102145986      0.0
#   2 TESS Sector 49 2022 TESS-SPOC     600  1102145986      0.0
#   3 TESS Sector 50 2022 TESS-SPOC     600  1102145986      0.0
# No data found for target "TIC 1102289520".
# SearchResult containing 0 data products.
# SearchResult containing 1 data products.
#
#  #     mission     year author exptime target_name distance
#                                   s                 arcsec
# --- -------------- ---- ------ ------- ----------- --------
#   0 TESS Sector 78 2024   SPOC     120  1200808784      0.0
# No data found for target "TIC 1680812612".
# SearchResult containing 0 data products.
# SearchResult containing 9 data products.
#
#  #     mission     year   author  exptime target_name distance
#                                      s                 arcsec
# --- -------------- ---- --------- ------- ----------- --------
#   0 TESS Sector 14 2019      SPOC     120  1713419350      0.0
#   1 TESS Sector 40 2021      SPOC     120  1713419350      0.0
#   2 TESS Sector 53 2022      SPOC     120  1713419350      0.0
#   3 TESS Sector 54 2022      SPOC     120  1713419350      0.0
#   4 TESS Sector 74 2024      SPOC     120  1713419350      0.0
#   5 TESS Sector 14 2019 TESS-SPOC    1800  1713419350      0.0
#   6 TESS Sector 40 2021 TESS-SPOC     600  1713419350      0.0
#   7 TESS Sector 53 2022 TESS-SPOC     600  1713419350      0.0
#   8 TESS Sector 54 2022 TESS-SPOC     600  1713419350      0.0
# No data found for target "TIC 1991765547".
# SearchResult containing 0 data products.
# No data found for target "TIC 2055637389".
# SearchResult containing 0 data products.
# SearchResult containing 4 data products.
#
#  #     mission     year   author  exptime target_name distance
#                                      s                 arcsec
# --- -------------- ---- --------- ------- ----------- --------
#   0 TESS Sector 52 2022      SPOC     120    21664200      0.0
#   1 TESS Sector 79 2024      SPOC      20    21664200      0.0
#   2 TESS Sector 79 2024      SPOC     120    21664200      0.0
#   3 TESS Sector 52 2022 TESS-SPOC     600    21664200      0.0

# %%
# Specify the Eclipsing CVs: 
TIC = 'TIC 219107776'

data_all = lk.search_lightcurve(TIC, author='SPOC', cadence='short')

data_all
# Out:
# SearchResult containing 29 data products.
#
#  #     mission     year author exptime target_name distance
#                                   s                 arcsec
# --- -------------- ---- ------ ------- ----------- --------
#   0 TESS Sector 14 2019   SPOC     120   219107776      0.0
#   1 TESS Sector 15 2019   SPOC     120   219107776      0.0
#   2 TESS Sector 16 2019   SPOC     120   219107776      0.0
#   3 TESS Sector 17 2019   SPOC     120   219107776      0.0
#   4 TESS Sector 18 2019   SPOC     120   219107776      0.0
#   5 TESS Sector 20 2019   SPOC     120   219107776      0.0
#   6 TESS Sector 26 2020   SPOC     120   219107776      0.0
#   7 TESS Sector 24 2020   SPOC     120   219107776      0.0
#   8 TESS Sector 21 2020   SPOC     120   219107776      0.0
# ...            ...  ...    ...     ...         ...      ...
#  19 TESS Sector 53 2022   SPOC     120   219107776      0.0
#  20 TESS Sector 51 2022   SPOC     120   219107776      0.0
#  21 TESS Sector 48 2022   SPOC     120   219107776      0.0
#  22 TESS Sector 54 2022   SPOC     120   219107776      0.0
#  23 TESS Sector 73 2023   SPOC     120   219107776      0.0
#  24 TESS Sector 77 2024   SPOC     120   219107776      0.0
#  25 TESS Sector 74 2024   SPOC     120   219107776      0.0
#  26 TESS Sector 75 2024   SPOC     120   219107776      0.0
#  27 TESS Sector 76 2024   SPOC     120   219107776      0.0
#  28 TESS Sector 78 2024   SPOC     120   219107776      0.0
# Length = 29 rows

# %%
data_all[0]
# Out:
# SearchResult containing 1 data products.
#
#  #     mission     year author exptime target_name distance
#                                   s                 arcsec
# --- -------------- ---- ------ ------- ----------- --------
#   0 TESS Sector 14 2019   SPOC     120   219107776      0.0

# %%
data = data_all[0]

lc = data.download_all().stitch()

p = lc.plot(linewidth = 0.5, marker = '.', color = 'r')

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
lc.to_timeseries()
# Out:
# /var/folders/dj/s7s773g53wg44p006fln3znw0000gn/T/ipykernel_82365/1963276583.py:1: LightkurveDeprecationWarning: `to_timeseries()` has been deprecated. `LightCurve` is a sub-class of Astropy TimeSeries as of Lightkurve v2.0 and no longer needs to be converted.
#   lc.to_timeseries()
# <TessLightCurve length=18424 LABEL="TIC 219107776" SECTOR=14 AUTHOR=SPOC FLUX_ORIGIN=pdcsap_flux>
#        time             flux      ...   pos_corr1      pos_corr2
#                                   ...      pix            pix
#        Time           float32     ...    float32        float32
# ------------------ -------------- ... -------------- --------------
# 1683.3538039952982  9.6186340e-01 ... -3.6085302e-03 -2.4877686e-02
# 1683.3551928842135  9.6925837e-01 ... -2.4708696e-03 -2.6225967e-02
#  1683.356581773122  9.2493480e-01 ... -6.8937452e-03 -2.7051156e-02
# 1683.3579706620221  9.3411064e-01 ... -7.9754870e-03 -3.1108106e-02
# 1683.3593595509221  9.2828804e-01 ... -6.5564462e-03 -2.2463121e-02
#  1683.360748439823  9.2671430e-01 ... -5.7092463e-03 -2.5228092e-02
# 1683.3621373287237  9.2391056e-01 ... -8.7647270e-03 -3.1278681e-02
# 1683.3635262176176  8.8552547e-01 ... -6.6128462e-03 -2.8517632e-02
#  1683.364915106511  9.0162855e-01 ... -8.6005749e-03 -2.3103556e-02
#                ...            ... ...            ...            ...
# 1710.1927324903263  9.2399299e-01 ...  3.1893530e-03 -1.7846301e-02
#  1710.194121386165  9.2187244e-01 ...  7.3580965e-03 -2.3002591e-02
# 1710.1955102820034  9.7011232e-01 ...  3.8330839e-03 -2.7665341e-02
#  1710.196899177845  9.7157633e-01 ...  6.4620436e-03 -1.4587134e-02
# 1710.1982880736837  9.6598589e-01 ...  5.8233719e-03 -1.9365821e-02
# 1710.1996769695265  1.0005255e+00 ...  7.1305628e-03 -2.4456307e-02
# 1710.2010658653649  9.8359269e-01 ...  2.8141586e-03 -1.6765218e-02
# 1710.2024547612064  9.8040789e-01 ...  4.7293492e-03 -2.0686908e-02
# 1710.2038436570479  9.8387760e-01 ...  9.2599904e-03 -1.9312363e-02

# %%
lc.flux
# Out:
# <MaskedQuantity [0.9618634 , 0.96925837, 0.9249348 , ..., 0.9835927 ,
#                  0.9804079 , 0.9838776 ]>

# %%
import pandas as pd

file_path = '/Users/mridul/Desktop/Physics Research Summer/CV-Analyzer/New Data/TIC 219107776.csv'
df = pd.read_csv(file_path)

plot = df.plot(x = 'cadenceno', y = 'pdcsap_flux', color = 'r')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 4
#       1 import pandas as pd
#       3 file_path = '/Users/mridul/Desktop/Physics Research Summer/CV-Analyzer/New Data/TIC 219107776.csv'
# ----> 4 df = pd.read_csv(file_path)
#       6 plot = df.plot(x = 'cadenceno', y = 'pdcsap_flux', color = 'r')
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/io/parsers/readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/io/common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/mridul/Desktop/Physics Research Summer/CV-Analyzer/New Data/TIC 219107776.csv'

# %%
import pandas as pd

file_path = '/Users/mridul/Desktop/Physics Research Summer/CV-Analyzer/New Data/TIC 219107776.csv'
df = pd.read_csv(file_path)

plot = df.plot(x = 'time', y = 'flux', color = 'r')

# %%
df.to_csv('/Users/mridul/Desktop/Physics Research Summer/CV-Analyzer/New Data/TIC 219107776 big.csv', index = False)
print(df.columns)

dataframe = df[['time', 'flux']]

dataframe.to_csv('/Users/mridul/Desktop/Physics Research Summer/CV-Analyzer/New Data/TIC 219107776 small.csv', index = False)

# %%
import numpy as np
from scipy.optimize import curve_fit

# Define the cosine function
def cosine_func(x, amplitude, frequency, phase):
    return amplitude * np.cos(2 * np.pi * frequency * x + phase)

# Extract the x and y data from the plot
x_data = plot.get_lines()[0].get_xdata()
y_data = plot.get_lines()[0].get_ydata()

# Perform the curve fitting
popt, pcov = curve_fit(cosine_func, x_data, y_data)

# Extract the optimized parameters
amplitude_opt = popt[0]
frequency_opt = popt[1]
phase_opt = popt[2]

# Generate the fitted curve
x_fit = np.linspace(min(x_data), max(x_data), 100)
y_fit = cosine_func(x_fit, amplitude_opt, frequency_opt, phase_opt)

plt.figure()
# Plot the fitted curve
plot.plot(x_fit, y_fit, color='red')

# Show the plot
plt.show()

# %%
periodogram = lc.to_periodogram()

fig_LS, ax_LS = plt.subplots(1,1,num=4)
periodogram.plot(ax=ax_LS)
ax_LS.set_xlabel(r'${\rm Frequency~[c/d]}$', fontsize=14)
ax_LS.set_ylabel(r'${\rm Amplitude}$', fontsize=14)
ax_LS.set_xlim(0, 350)
#fig_LS.tight_layout()
plt.show()
